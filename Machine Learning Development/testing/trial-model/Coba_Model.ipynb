# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import zipfile

# %%
import tensorflow as tf
import tensorflow_hub as hub
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from tensorflow.keras.utils import get_file
from sklearn.metrics import roc_curve, auc, confusion_matrix
from imblearn.metrics import sensitivity_score, specificity_score

import os
import glob
import zipfile
import random

# to get consistent results after multiple runs
tf.random.set_seed(7)
np.random.seed(7)
random.seed(7)

# 0 for benign, 1 for malignant
class_names = ["benign", "malignant"]
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/externals/six.py:31: FutureWarning: The module is deprecated in version 0.21 and will be removed in version 0.23 since we've dropped support for Python 2.7. Please rely on the official version of six (https://pypi.org/project/six/).
#   "(https://pypi.org/project/six/).", FutureWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:144: FutureWarning: The sklearn.neighbors.base module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.neighbors. Anything that cannot be imported from sklearn.neighbors is now part of the private API.
#   warnings.warn(message, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:144: FutureWarning: The sklearn.metrics.classification module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.metrics. Anything that cannot be imported from sklearn.metrics is now part of the private API.
#   warnings.warn(message, FutureWarning)

# %%
def download_and_extract_dataset():
  # dataset dari https://github.com/udacity/dermatologist-ai
  train_url = "https://s3-us-west-1.amazonaws.com/udacity-dlnfd/datasets/skin-cancer/train.zip"
  valid_url = "https://s3-us-west-1.amazonaws.com/udacity-dlnfd/datasets/skin-cancer/valid.zip"
  test_url  = "https://s3-us-west-1.amazonaws.com/udacity-dlnfd/datasets/skin-cancer/test.zip"
  for i, download_link in enumerate([valid_url, train_url, test_url]):
    temp_file = f"temp{i}.zip"
    data_dir = get_file(origin=download_link, fname=os.path.join(os.getcwd(), temp_file))
    print("Extracting", download_link)
    with zipfile.ZipFile(data_dir, "r") as z:
      z.extractall("data")

    os.remove(temp_file)


download_and_extract_dataset()
# Out:
# Downloading data from https://s3-us-west-1.amazonaws.com/udacity-dlnfd/datasets/skin-cancer/valid.zip
# 864542720/864538487 [==============================] - 46s 0us/step
# Extracting https://s3-us-west-1.amazonaws.com/udacity-dlnfd/datasets/skin-cancer/valid.zip
# Downloading data from https://s3-us-west-1.amazonaws.com/udacity-dlnfd/datasets/skin-cancer/train.zip
# 5736562688/5736557430 [==============================] - 281s 0us/step
# Extracting https://s3-us-west-1.amazonaws.com/udacity-dlnfd/datasets/skin-cancer/train.zip
# Downloading data from https://s3-us-west-1.amazonaws.com/udacity-dlnfd/datasets/skin-cancer/test.zip
# 5528641536/5528640507 [==============================] - 266s 0us/step
# Extracting https://s3-us-west-1.amazonaws.com/udacity-dlnfd/datasets/skin-cancer/test.zip

# %%
# preparing data
# generate metadata CSV  
def generate_csv(folder, label2int):
    folder_name = os.path.basename(folder)
    labels = list(label2int)
    # generate file CSV
    df = pd.DataFrame(columns=["filepath", "label"])
    i = 0
    for label in labels:
        print("Reading", os.path.join(folder, label, "*"))
        for filepath in glob.glob(os.path.join(folder, label, "*")):
            df.loc[i] = [filepath, label2int[label]]
            i += 1
    output_file = f"{folder_name}.csv"
    print("Saving", output_file)
    df.to_csv(output_file)

# labelling
generate_csv("data/train", {"nevus": 0, "seborrheic_keratosis": 0, "melanoma": 1})
generate_csv("data/valid", {"nevus": 0, "seborrheic_keratosis": 0, "melanoma": 1})
generate_csv("data/test", {"nevus": 0, "seborrheic_keratosis": 0, "melanoma": 1})
# Out:
# Reading data/train/nevus/*
# Reading data/train/seborrheic_keratosis/*
# Reading data/train/melanoma/*
# Saving train.csv
# Reading data/valid/nevus/*
# Reading data/valid/seborrheic_keratosis/*
# Reading data/valid/melanoma/*
# Saving valid.csv
# Reading data/test/nevus/*
# Reading data/test/seborrheic_keratosis/*
# Reading data/test/melanoma/*
# Saving test.csv

# %%
# loading data
train_metadata_filename = "train.csv"
valid_metadata_filename = "valid.csv"
# buat ke dataframe
df_train = pd.read_csv(train_metadata_filename)
df_valid = pd.read_csv(valid_metadata_filename)
n_training_samples = len(df_train)
n_validation_samples = len(df_valid)
print("Number of training samples:", n_training_samples)
print("Number of validation samples:", n_validation_samples)
train_ds = tf.data.Dataset.from_tensor_slices((df_train["filepath"], df_train["label"]))
valid_ds = tf.data.Dataset.from_tensor_slices((df_valid["filepath"], df_valid["label"]))
# Out:
# Number of training samples: 2000
# Number of validation samples: 150

# %%
# preprocess data
def decode_img(img):
  # convert compressed string ke 3D uint8 tensor
  img = tf.image.decode_jpeg(img, channels=3)
  # convert gambar ke float antara [0-1].
  img = tf.image.convert_image_dtype(img, tf.float32)
  # resize image.
  return tf.image.resize(img, [299, 299])


def process_path(filepath, label):
  # load raw data dari file bentuknya string
  img = tf.io.read_file(filepath)
  img = decode_img(img)
  return img, label


valid_ds = valid_ds.map(process_path)
train_ds = train_ds.map(process_path)
# test_ds = test_ds
for image, label in train_ds.take(1):
    print("Image shape:", image.shape)
    print("Label:", label.numpy())
# Out:
# Image shape: (299, 299, 3)
# Label: 0

# %%
# training hyper parameter
batch_size = 64
optimizer = "rmsprop"

def prepare_for_training(ds, cache=True, batch_size=64, shuffle_buffer_size=1000):
  if cache:
    if isinstance(cache, str):
      ds = ds.cache(cache)
    else:
      ds = ds.cache()
  # shuffle dataset
  ds = ds.shuffle(buffer_size=shuffle_buffer_size)
  # Repeat
  ds = ds.repeat()
  # split sesuai batch
  ds = ds.batch(batch_size)
  ds = ds.prefetch(buffer_size=tf.data.experimental.AUTOTUNE)
  return ds

valid_ds = prepare_for_training(valid_ds, batch_size=batch_size, cache="valid-cached-data")
train_ds = prepare_for_training(train_ds, batch_size=batch_size, cache="train-cached-data")

# %%
batch = next(iter(valid_ds))

#liatin isi dataset
def show_batch(batch):
  plt.figure(figsize=(12,12))
  for n in range(25):
      ax = plt.subplot(5,5,n+1)
      plt.imshow(batch[0][n])
      plt.title(class_names[batch[1][n].numpy()].title())
      plt.axis('off')
        
show_batch(batch)

# %%
# bikin model tf learning
# pake model InceptionV3 model & pre-trained weights
module_url = "https://tfhub.dev/google/tf2-preview/inception_v3/feature_vector/4"
m = tf.keras.Sequential([
    hub.KerasLayer(module_url, output_shape=[2048], trainable=False),
    #TAMBAHAN BANYAK LAYER TERSERAH KITA
    tf.keras.layers.Dense(1, activation="sigmoid")
])

m.build([None, 299, 299, 3])
m.compile(loss="binary_crossentropy", optimizer=optimizer, metrics=["accuracy"])
m.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# keras_layer (KerasLayer)     (None, 2048)              21802784
# _________________________________________________________________
# dense (Dense)                (None, 1)                 2049
# =================================================================
# Total params: 21,804,833
# Trainable params: 2,049
# Non-trainable params: 21,802,784
# _________________________________________________________________

# %%
model_name = f"benign-vs-malignant_{batch_size}_{optimizer}"
tensorboard = tf.keras.callbacks.TensorBoard(log_dir=os.path.join("logs", model_name))
# saves model checkpoint yg paling bagus hasilnya
modelcheckpoint = tf.keras.callbacks.ModelCheckpoint(model_name + "_{val_loss:.3f}.h5", save_best_only=True, verbose=1)

history = m.fit(train_ds, validation_data=valid_ds, 
                steps_per_epoch=n_training_samples // batch_size, 
                validation_steps=n_validation_samples // batch_size, verbose=1, epochs=100,
                callbacks=[tensorboard, modelcheckpoint])
# Out:
# Epoch 1/100
# 31/31 [==============================] - 421s 7s/step - loss: 0.3536 - accuracy: 0.8053 - val_loss: 0.5809 - val_accuracy: 0.7891
#
# Epoch 00001: val_loss improved from inf to 0.58087, saving model to benign-vs-malignant_64_rmsprop_0.581.h5
# Epoch 2/100
# 31/31 [==============================] - 26s 837ms/step - loss: 0.2750 - accuracy: 0.8877 - val_loss: 0.5173 - val_accuracy: 0.8047
#
# Epoch 00002: val_loss improved from 0.58087 to 0.51727, saving model to benign-vs-malignant_64_rmsprop_0.517.h5
# Epoch 3/100
# 31/31 [==============================] - 17s 547ms/step - loss: 0.2543 - accuracy: 0.8995 - val_loss: 0.4857 - val_accuracy: 0.7969
#
# Epoch 00003: val_loss improved from 0.51727 to 0.48570, saving model to benign-vs-malignant_64_rmsprop_0.486.h5
# Epoch 4/100
# 31/31 [==============================] - 17s 554ms/step - loss: 0.2494 - accuracy: 0.8989 - val_loss: 0.4959 - val_accuracy: 0.7812
#
# Epoch 00004: val_loss did not improve from 0.48570
# Epoch 5/100
# 31/31 [==============================] - 17s 550ms/step - loss: 0.2503 - accuracy: 0.8991 - val_loss: 0.5215 - val_accuracy: 0.7266
#
# Epoch 00005: val_loss did not improve from 0.48570
# Epoch 6/100
# 31/31 [==============================] - 17s 551ms/step - loss: 0.2610 - accuracy: 0.8958 - val_loss: 0.4931 - val_accuracy: 0.7500
#
# Epoch 00006: val_loss did not improve from 0.48570
# Epoch 7/100
# 31/31 [==============================] - 17s 552ms/step - loss: 0.2634 - accuracy: 0.8904 - val_loss: 0.4566 - val_accuracy: 0.7891
#
# Epoch 00007: val_loss improved from 0.48570 to 0.45658, saving model to benign-vs-malignant_64_rmsprop_0.457.h5
# Epoch 8/100
# 31/31 [==============================] - 17s 550ms/step - loss: 0.2644 - accuracy: 0.8920 - val_loss: 0.4743 - val_accuracy: 0.7656
#
# Epoch 00008: val_loss did not improve from 0.45658
# Epoch 9/100
# 31/31 [==============================] - 17s 550ms/step - loss: 0.2889 - accuracy: 0.8767 - val_loss: 0.4377 - val_accuracy: 0.7891
#
# Epoch 00009: val_loss improved from 0.45658 to 0.43769, saving model to benign-vs-malignant_64_rmsprop_0.438.h5
# Epoch 10/100
# 31/31 [==============================] - 17s 553ms/step - loss: 0.2468 - accuracy: 0.9000 - val_loss: 0.4853 - val_accuracy: 0.7266
#
# Epoch 00010: val_loss did not improve from 0.43769
# Epoch 11/100
# 31/31 [==============================] - 17s 549ms/step - loss: 0.2556 - accuracy: 0.8935 - val_loss: 0.4486 - val_accuracy: 0.8047
#
# Epoch 00011: val_loss did not improve from 0.43769
# Epoch 12/100
# 31/31 [==============================] - 17s 552ms/step - loss: 0.2760 - accuracy: 0.8820 - val_loss: 0.4474 - val_accuracy: 0.8281
#
# Epoch 00012: val_loss did not improve from 0.43769
# Epoch 13/100
# 31/31 [==============================] - 17s 550ms/step - loss: 0.3208 - accuracy: 0.8559 - val_loss: 0.4315 - val_accuracy: 0.8203
#
# Epoch 00013: val_loss improved from 0.43769 to 0.43153, saving model to benign-vs-malignant_64_rmsprop_0.432.h5
# Epoch 14/100
# 31/31 [==============================] - 17s 552ms/step - loss: 0.2459 - accuracy: 0.8923 - val_loss: 0.4741 - val_accuracy: 0.7734
#
# Epoch 00014: val_loss did not improve from 0.43153
# Epoch 15/100
# 31/31 [==============================] - 17s 551ms/step - loss: 0.3124 - accuracy: 0.8521 - val_loss: 0.4507 - val_accuracy: 0.8203
#
# Epoch 00015: val_loss did not improve from 0.43153
# Epoch 16/100
# 31/31 [==============================] - 17s 552ms/step - loss: 0.2882 - accuracy: 0.8774 - val_loss: 0.4285 - val_accuracy: 0.8359
#
# Epoch 00016: val_loss improved from 0.43153 to 0.42846, saving model to benign-vs-malignant_64_rmsprop_0.428.h5
# Epoch 17/100
# 31/31 [==============================] - 17s 552ms/step - loss: 0.3092 - accuracy: 0.8687 - val_loss: 0.4713 - val_accuracy: 0.7734
#
# Epoch 00017: val_loss did not improve from 0.42846
# Epoch 18/100
# 31/31 [==============================] - 17s 552ms/step - loss: 0.2853 - accuracy: 0.8881 - val_loss: 0.4809 - val_accuracy: 0.7500
#
# Epoch 00018: val_loss did not improve from 0.42846
# Epoch 19/100
# 31/31 [==============================] - 17s 550ms/step - loss: 0.3135 - accuracy: 0.8586 - val_loss: 0.4291 - val_accuracy: 0.8359
#
# Epoch 00019: val_loss did not improve from 0.42846
# Epoch 20/100
# 31/31 [==============================] - 17s 552ms/step - loss: 0.2785 - accuracy: 0.8911 - val_loss: 0.4513 - val_accuracy: 0.8281
#
# Epoch 00020: val_loss did not improve from 0.42846
# Epoch 21/100
# 31/31 [==============================] - 17s 550ms/step - loss: 0.2897 - accuracy: 0.8763 - val_loss: 0.4365 - val_accuracy: 0.8125
#
# Epoch 00021: val_loss did not improve from 0.42846
# Epoch 22/100
# 31/31 [==============================] - 17s 550ms/step - loss: 0.2922 - accuracy: 0.8686 - val_loss: 0.4897 - val_accuracy: 0.7344
#
# Epoch 00022: val_loss did not improve from 0.42846
# Epoch 23/100
# 31/31 [==============================] - 17s 552ms/step - loss: 0.3049 - accuracy: 0.8703 - val_loss: 0.4867 - val_accuracy: 0.7969
#
# Epoch 00023: val_loss did not improve from 0.42846
# Epoch 24/100
# 31/31 [==============================] - 17s 550ms/step - loss: 0.3004 - accuracy: 0.8629 - val_loss: 0.4685 - val_accuracy: 0.8047
#
# Epoch 00024: val_loss did not improve from 0.42846
# Epoch 25/100
# 31/31 [==============================] - 17s 550ms/step - loss: 0.3001 - accuracy: 0.8641 - val_loss: 0.4663 - val_accuracy: 0.7891
#
# Epoch 00025: val_loss did not improve from 0.42846
# Epoch 26/100
# 31/31 [==============================] - 17s 552ms/step - loss: 0.2831 - accuracy: 0.8831 - val_loss: 0.4338 - val_accuracy: 0.8203
#
# Epoch 00026: val_loss did not improve from 0.42846
# Epoch 27/100
# 31/31 [==============================] - 17s 549ms/step - loss: 0.2954 - accuracy: 0.8744 - val_loss: 0.4555 - val_accuracy: 0.8125
#
# Epoch 00027: val_loss did not improve from 0.42846
# Epoch 28/100
# 31/31 [==============================] - 17s 552ms/step - loss: 0.3002 - accuracy: 0.8693 - val_loss: 0.4726 - val_accuracy: 0.8281
#
# Epoch 00028: val_loss did not improve from 0.42846
# Epoch 29/100
# 31/31 [==============================] - 17s 548ms/step - loss: 0.3352 - accuracy: 0.8371 - val_loss: 0.4495 - val_accuracy: 0.8438
#
# Epoch 00029: val_loss did not improve from 0.42846
# Epoch 30/100
# 31/31 [==============================] - 17s 552ms/step - loss: 0.3156 - accuracy: 0.8577 - val_loss: 0.4114 - val_accuracy: 0.8438
#
# Epoch 00030: val_loss improved from 0.42846 to 0.41138, saving model to benign-vs-malignant_64_rmsprop_0.411.h5
# Epoch 31/100
# 31/31 [==============================] - 17s 552ms/step - loss: 0.3005 - accuracy: 0.8809 - val_loss: 0.4518 - val_accuracy: 0.7969
#
# Epoch 00031: val_loss did not improve from 0.41138
# Epoch 32/100
# 31/31 [==============================] - 17s 551ms/step - loss: 0.3007 - accuracy: 0.8739 - val_loss: 0.3809 - val_accuracy: 0.8359
#
# Epoch 00032: val_loss improved from 0.41138 to 0.38093, saving model to benign-vs-malignant_64_rmsprop_0.381.h5
# Epoch 33/100
# 31/31 [==============================] - 17s 552ms/step - loss: 0.3119 - accuracy: 0.8594 - val_loss: 0.4428 - val_accuracy: 0.7891
#
# Epoch 00033: val_loss did not improve from 0.38093
# Epoch 34/100
# 31/31 [==============================] - 17s 552ms/step - loss: 0.2982 - accuracy: 0.8693 - val_loss: 0.4256 - val_accuracy: 0.8281
#
# Epoch 00034: val_loss did not improve from 0.38093
# Epoch 35/100
# 31/31 [==============================] - 17s 550ms/step - loss: 0.3280 - accuracy: 0.8511 - val_loss: 0.4235 - val_accuracy: 0.8125
#
# Epoch 00035: val_loss did not improve from 0.38093
# Epoch 36/100
# 31/31 [==============================] - 17s 552ms/step - loss: 0.2939 - accuracy: 0.8874 - val_loss: 0.4188 - val_accuracy: 0.8125
#
# Epoch 00036: val_loss did not improve from 0.38093
# Epoch 37/100
# 31/31 [==============================] - 17s 548ms/step - loss: 0.3067 - accuracy: 0.8725 - val_loss: 0.4482 - val_accuracy: 0.8125
#
# Epoch 00037: val_loss did not improve from 0.38093
# Epoch 38/100
# 31/31 [==============================] - 17s 553ms/step - loss: 0.3037 - accuracy: 0.8756 - val_loss: 0.4889 - val_accuracy: 0.7812
#
# Epoch 00038: val_loss did not improve from 0.38093
# Epoch 39/100
# 31/31 [==============================] - 17s 551ms/step - loss: 0.3223 - accuracy: 0.8487 - val_loss: 0.4411 - val_accuracy: 0.8203
#
# Epoch 00039: val_loss did not improve from 0.38093
# Epoch 40/100
# 31/31 [==============================] - 17s 549ms/step - loss: 0.2888 - accuracy: 0.8833 - val_loss: 0.4063 - val_accuracy: 0.8281
#
# Epoch 00040: val_loss did not improve from 0.38093
# Epoch 41/100
# 31/31 [==============================] - 17s 551ms/step - loss: 0.3199 - accuracy: 0.8556 - val_loss: 0.4536 - val_accuracy: 0.8125
#
# Epoch 00041: val_loss did not improve from 0.38093
# Epoch 42/100
# 31/31 [==============================] - 17s 552ms/step - loss: 0.2996 - accuracy: 0.8740 - val_loss: 0.4399 - val_accuracy: 0.8203
#
# Epoch 00042: val_loss did not improve from 0.38093
# Epoch 43/100
# 31/31 [==============================] - 17s 549ms/step - loss: 0.3004 - accuracy: 0.8728 - val_loss: 0.4886 - val_accuracy: 0.8047
#
# Epoch 00043: val_loss did not improve from 0.38093
# Epoch 44/100
# 31/31 [==============================] - 17s 551ms/step - loss: 0.3116 - accuracy: 0.8644 - val_loss: 0.4703 - val_accuracy: 0.7734
#
# Epoch 00044: val_loss did not improve from 0.38093
# Epoch 45/100
# 31/31 [==============================] - 17s 550ms/step - loss: 0.3091 - accuracy: 0.8721 - val_loss: 0.4792 - val_accuracy: 0.7969
#
# Epoch 00045: val_loss did not improve from 0.38093
# Epoch 46/100
# 31/31 [==============================] - 17s 550ms/step - loss: 0.2922 - accuracy: 0.8828 - val_loss: 0.4703 - val_accuracy: 0.8203
#
# Epoch 00046: val_loss did not improve from 0.38093
# Epoch 47/100
# 31/31 [==============================] - 17s 552ms/step - loss: 0.3064 - accuracy: 0.8622 - val_loss: 0.4683 - val_accuracy: 0.7969
#
# Epoch 00047: val_loss did not improve from 0.38093
# Epoch 48/100
# 31/31 [==============================] - 17s 550ms/step - loss: 0.3043 - accuracy: 0.8786 - val_loss: 0.4412 - val_accuracy: 0.8125
#
# Epoch 00048: val_loss did not improve from 0.38093
# Epoch 49/100
# 31/31 [==============================] - 17s 551ms/step - loss: 0.3075 - accuracy: 0.8563 - val_loss: 0.4598 - val_accuracy: 0.8125
#
# Epoch 00049: val_loss did not improve from 0.38093
# Epoch 50/100
# 31/31 [==============================] - 17s 550ms/step - loss: 0.3079 - accuracy: 0.8714 - val_loss: 0.4730 - val_accuracy: 0.7578
#
# Epoch 00050: val_loss did not improve from 0.38093
# Epoch 51/100
# 31/31 [==============================] - 17s 551ms/step - loss: 0.3066 - accuracy: 0.8688 - val_loss: 0.4193 - val_accuracy: 0.8359
#
# Epoch 00051: val_loss did not improve from 0.38093
# Epoch 52/100
# 31/31 [==============================] - 17s 550ms/step - loss: 0.3148 - accuracy: 0.8623 - val_loss: 0.4257 - val_accuracy: 0.8125
#
# Epoch 00052: val_loss did not improve from 0.38093
# Epoch 53/100
# 31/31 [==============================] - 17s 551ms/step - loss: 0.3052 - accuracy: 0.8678 - val_loss: 0.4372 - val_accuracy: 0.8125
#
# Epoch 00053: val_loss did not improve from 0.38093
# Epoch 54/100
# 31/31 [==============================] - 17s 551ms/step - loss: 0.3244 - accuracy: 0.8674 - val_loss: 0.4427 - val_accuracy: 0.8203
#
# Epoch 00054: val_loss did not improve from 0.38093
# Epoch 55/100
# 31/31 [==============================] - 17s 552ms/step - loss: 0.3140 - accuracy: 0.8612 - val_loss: 0.4673 - val_accuracy: 0.8125
#
# Epoch 00055: val_loss did not improve from 0.38093
# Epoch 56/100
# 31/31 [==============================] - 17s 548ms/step - loss: 0.3153 - accuracy: 0.8515 - val_loss: 0.4410 - val_accuracy: 0.8125
#
# Epoch 00056: val_loss did not improve from 0.38093
# Epoch 57/100
# 31/31 [==============================] - 17s 553ms/step - loss: 0.3503 - accuracy: 0.8242 - val_loss: 0.4567 - val_accuracy: 0.8125
#
# Epoch 00057: val_loss did not improve from 0.38093
# Epoch 58/100
# 31/31 [==============================] - 17s 549ms/step - loss: 0.3075 - accuracy: 0.8807 - val_loss: 0.3856 - val_accuracy: 0.8516
#
# Epoch 00058: val_loss did not improve from 0.38093
# Epoch 59/100
# 31/31 [==============================] - 17s 552ms/step - loss: 0.3041 - accuracy: 0.8756 - val_loss: 0.4781 - val_accuracy: 0.7812
#
# Epoch 00059: val_loss did not improve from 0.38093
# Epoch 60/100
# 31/31 [==============================] - 17s 551ms/step - loss: 0.3252 - accuracy: 0.8657 - val_loss: 0.4487 - val_accuracy: 0.7891
#
# Epoch 00060: val_loss did not improve from 0.38093
# Epoch 61/100
# 31/31 [==============================] - 17s 550ms/step - loss: 0.3136 - accuracy: 0.8700 - val_loss: 0.4388 - val_accuracy: 0.8125
#
# Epoch 00061: val_loss did not improve from 0.38093
# Epoch 62/100
# 31/31 [==============================] - 17s 550ms/step - loss: 0.3104 - accuracy: 0.8747 - val_loss: 0.5152 - val_accuracy: 0.8125
#
# Epoch 00062: val_loss did not improve from 0.38093
# Epoch 63/100
# 31/31 [==============================] - 17s 553ms/step - loss: 0.3213 - accuracy: 0.8739 - val_loss: 0.4493 - val_accuracy: 0.8203
#
# Epoch 00063: val_loss did not improve from 0.38093
# Epoch 64/100
# 31/31 [==============================] - 17s 549ms/step - loss: 0.3052 - accuracy: 0.8816 - val_loss: 0.5012 - val_accuracy: 0.8125
#
# Epoch 00064: val_loss did not improve from 0.38093
# Epoch 65/100
# 31/31 [==============================] - 17s 553ms/step - loss: 0.3075 - accuracy: 0.8725 - val_loss: 0.4283 - val_accuracy: 0.8203
#
# Epoch 00065: val_loss did not improve from 0.38093
# Epoch 66/100
# 31/31 [==============================] - 17s 549ms/step - loss: 0.3155 - accuracy: 0.8657 - val_loss: 0.4797 - val_accuracy: 0.8203
#
# Epoch 00066: val_loss did not improve from 0.38093
# Epoch 67/100
# 31/31 [==============================] - 17s 552ms/step - loss: 0.3082 - accuracy: 0.8719 - val_loss: 0.4852 - val_accuracy: 0.8203
#
# Epoch 00067: val_loss did not improve from 0.38093
# Epoch 68/100
# 31/31 [==============================] - 17s 550ms/step - loss: 0.3010 - accuracy: 0.8736 - val_loss: 0.4717 - val_accuracy: 0.8125
#
# Epoch 00068: val_loss did not improve from 0.38093
# Epoch 69/100
# 31/31 [==============================] - 17s 551ms/step - loss: 0.2910 - accuracy: 0.8815 - val_loss: 0.4308 - val_accuracy: 0.8359
#
# Epoch 00069: val_loss did not improve from 0.38093
# Epoch 70/100
# 31/31 [==============================] - 17s 550ms/step - loss: 0.3077 - accuracy: 0.8717 - val_loss: 0.4513 - val_accuracy: 0.8047
#
# Epoch 00070: val_loss did not improve from 0.38093
# Epoch 71/100
# 31/31 [==============================] - 17s 553ms/step - loss: 0.3024 - accuracy: 0.8692 - val_loss: 0.4857 - val_accuracy: 0.8359
#
# Epoch 00071: val_loss did not improve from 0.38093
# Epoch 72/100
# 31/31 [==============================] - 17s 549ms/step - loss: 0.3054 - accuracy: 0.8796 - val_loss: 0.4941 - val_accuracy: 0.8281
#
# Epoch 00072: val_loss did not improve from 0.38093
# Epoch 73/100
# 31/31 [==============================] - 17s 552ms/step - loss: 0.3177 - accuracy: 0.8629 - val_loss: 0.6632 - val_accuracy: 0.8047
#
# Epoch 00073: val_loss did not improve from 0.38093
# Epoch 74/100
# 31/31 [==============================] - 17s 549ms/step - loss: 0.3195 - accuracy: 0.8520 - val_loss: 0.4338 - val_accuracy: 0.8516
#
# Epoch 00074: val_loss did not improve from 0.38093
# Epoch 75/100
# 31/31 [==============================] - 17s 552ms/step - loss: 0.3143 - accuracy: 0.8635 - val_loss: 0.5429 - val_accuracy: 0.8359
#
# Epoch 00075: val_loss did not improve from 0.38093
# Epoch 76/100
# 31/31 [==============================] - 17s 549ms/step - loss: 0.3096 - accuracy: 0.8737 - val_loss: 0.7271 - val_accuracy: 0.7891
#
# Epoch 00076: val_loss did not improve from 0.38093
# Epoch 77/100
# 31/31 [==============================] - 17s 553ms/step - loss: 0.3218 - accuracy: 0.8585 - val_loss: 0.6424 - val_accuracy: 0.8125
#
# Epoch 00077: val_loss did not improve from 0.38093
# Epoch 78/100
# 31/31 [==============================] - 17s 549ms/step - loss: 0.2948 - accuracy: 0.8706 - val_loss: 0.6441 - val_accuracy: 0.8125
#
# Epoch 00078: val_loss did not improve from 0.38093
# Epoch 79/100
# 31/31 [==============================] - 17s 553ms/step - loss: 0.2997 - accuracy: 0.8797 - val_loss: 0.8496 - val_accuracy: 0.7891
#
# Epoch 00079: val_loss did not improve from 0.38093
# Epoch 80/100
# 31/31 [==============================] - 17s 548ms/step - loss: 0.2923 - accuracy: 0.8802 - val_loss: 0.9046 - val_accuracy: 0.7891
#
# Epoch 00080: val_loss did not improve from 0.38093
# Epoch 81/100
# 31/31 [==============================] - 17s 552ms/step - loss: 0.2958 - accuracy: 0.8714 - val_loss: 0.7312 - val_accuracy: 0.8047
#
# Epoch 00081: val_loss did not improve from 0.38093
# Epoch 82/100
# 31/31 [==============================] - 17s 550ms/step - loss: 0.2985 - accuracy: 0.8782 - val_loss: 0.8432 - val_accuracy: 0.7969
#
# Epoch 00082: val_loss did not improve from 0.38093
# Epoch 83/100
# 31/31 [==============================] - 17s 552ms/step - loss: 0.2832 - accuracy: 0.8867 - val_loss: 0.8832 - val_accuracy: 0.8047
#
# Epoch 00083: val_loss did not improve from 0.38093
# Epoch 84/100
# 31/31 [==============================] - 17s 550ms/step - loss: 0.2956 - accuracy: 0.8801 - val_loss: 0.9028 - val_accuracy: 0.7969
#
# Epoch 00084: val_loss did not improve from 0.38093
# Epoch 85/100
# 31/31 [==============================] - 17s 550ms/step - loss: 0.2790 - accuracy: 0.8868 - val_loss: 0.7632 - val_accuracy: 0.8125
#
# Epoch 00085: val_loss did not improve from 0.38093
# Epoch 86/100
# 31/31 [==============================] - 17s 549ms/step - loss: 0.2930 - accuracy: 0.8728 - val_loss: 0.9531 - val_accuracy: 0.7891
#
# Epoch 00086: val_loss did not improve from 0.38093
# Epoch 87/100
# 31/31 [==============================] - 17s 553ms/step - loss: 0.2698 - accuracy: 0.8981 - val_loss: 0.8795 - val_accuracy: 0.8047
#
# Epoch 00087: val_loss did not improve from 0.38093
# Epoch 88/100
# 31/31 [==============================] - 17s 550ms/step - loss: 0.2586 - accuracy: 0.9000 - val_loss: 0.9779 - val_accuracy: 0.7812
#
# Epoch 00088: val_loss did not improve from 0.38093
# Epoch 89/100
# 31/31 [==============================] - 17s 552ms/step - loss: 0.2505 - accuracy: 0.8962 - val_loss: 0.8737 - val_accuracy: 0.8125
#
# Epoch 00089: val_loss did not improve from 0.38093
# Epoch 90/100
# 31/31 [==============================] - 17s 548ms/step - loss: 0.2501 - accuracy: 0.8933 - val_loss: 0.7524 - val_accuracy: 0.8125
#
# Epoch 00090: val_loss did not improve from 0.38093
# Epoch 91/100
# 31/31 [==============================] - 17s 552ms/step - loss: 0.2493 - accuracy: 0.8922 - val_loss: 0.8248 - val_accuracy: 0.8125
#
# Epoch 00091: val_loss did not improve from 0.38093
# Epoch 92/100
# 31/31 [==============================] - 17s 549ms/step - loss: 0.2438 - accuracy: 0.9088 - val_loss: 0.8235 - val_accuracy: 0.7969
#
# Epoch 00092: val_loss did not improve from 0.38093
# Epoch 93/100
# 31/31 [==============================] - 17s 552ms/step - loss: 0.2399 - accuracy: 0.9032 - val_loss: 0.7638 - val_accuracy: 0.8047
#
# Epoch 00093: val_loss did not improve from 0.38093
# Epoch 94/100
# 31/31 [==============================] - 17s 549ms/step - loss: 0.2166 - accuracy: 0.9099 - val_loss: 0.9159 - val_accuracy: 0.8047
#
# Epoch 00094: val_loss did not improve from 0.38093
# Epoch 95/100
# 31/31 [==============================] - 17s 553ms/step - loss: 0.2334 - accuracy: 0.9089 - val_loss: 0.7970 - val_accuracy: 0.8203
#
# Epoch 00095: val_loss did not improve from 0.38093
# Epoch 96/100
# 31/31 [==============================] - 17s 549ms/step - loss: 0.2195 - accuracy: 0.9153 - val_loss: 0.7626 - val_accuracy: 0.8047
#
# Epoch 00096: val_loss did not improve from 0.38093
# Epoch 97/100
# 31/31 [==============================] - 17s 552ms/step - loss: 0.2163 - accuracy: 0.9143 - val_loss: 0.6968 - val_accuracy: 0.8125
#
# Epoch 00097: val_loss did not improve from 0.38093
# Epoch 98/100
# 31/31 [==============================] - 17s 551ms/step - loss: 0.1923 - accuracy: 0.9237 - val_loss: 0.9532 - val_accuracy: 0.7734
#
# Epoch 00098: val_loss did not improve from 0.38093
# Epoch 99/100
# 31/31 [==============================] - 17s 550ms/step - loss: 0.1995 - accuracy: 0.9235 - val_loss: 0.7845 - val_accuracy: 0.7891
#
# Epoch 00099: val_loss did not improve from 0.38093
# Epoch 100/100
# 31/31 [==============================] - 17s 551ms/step - loss: 0.1976 - accuracy: 0.9190 - val_loss: 0.7525 - val_accuracy: 0.8125
#
# Epoch 00100: val_loss did not improve from 0.38093

# %%
# evaluation
# load testing set
test_metadata_filename = "test.csv"
df_test = pd.read_csv(test_metadata_filename)
n_testing_samples = len(df_test)
print("Number of testing samples:", n_testing_samples)
test_ds = tf.data.Dataset.from_tensor_slices((df_test["filepath"], df_test["label"]))

def prepare_for_testing(ds, cache=True, shuffle_buffer_size=1000):
  if cache:
    if isinstance(cache, str):
      ds = ds.cache(cache)
    else:
      ds = ds.cache()
  ds = ds.shuffle(buffer_size=shuffle_buffer_size)
  return ds

test_ds = test_ds.map(process_path)
test_ds = prepare_for_testing(test_ds, cache="test-cached-data")
# Out:
# Number of testing samples: 600

# %%
# convert testing set ke numpy array
y_test = np.zeros((n_testing_samples,))
X_test = np.zeros((n_testing_samples, 299, 299, 3))
for i, (img, label) in enumerate(test_ds.take(n_testing_samples)):
  X_test[i] = img
  y_test[i] = label.numpy()

print("y_test.shape:", y_test.shape)
# Out:
# y_test.shape: (600,)

# %%
m.load_weights("benign-vs-malignant_64_rmsprop_0.381.h5")

# %%
print("Evaluating the model...")
loss, accuracy = m.evaluate(X_test, y_test, verbose=0)
print("Loss:", loss, "  Accuracy:", accuracy)
# Out:
# Evaluating the model...
# Loss: 0.45552149415016174   Accuracy: 0.7983333468437195

# %%
def get_predictions(threshold=None):
  y_pred = m.predict(X_test)
  if not threshold:
    threshold = 0.5
  result = np.zeros((n_testing_samples,))
  for i in range(n_testing_samples):
    # test probabilitas melanoma
    if y_pred[i][0] >= threshold:
      result[i] = 1
    # else, dia akan 0 (benign)
  return result

threshold = 0.23
y_pred = get_predictions(threshold)

# %%
def plot_confusion_matrix(y_test, y_pred):
  cmn = confusion_matrix(y_test, y_pred)
  cmn = cmn.astype('float') / cmn.sum(axis=1)[:, np.newaxis]
  print(cmn)
  fig, ax = plt.subplots(figsize=(10,10))
  sns.heatmap(cmn, annot=True, fmt='.2f', 
              xticklabels=[f"pred_{c}" for c in class_names], 
              yticklabels=[f"true_{c}" for c in class_names],
              cmap="Blues"
              )
  plt.ylabel('Actual')
  plt.xlabel('Predicted')
  
  plt.show()

plot_confusion_matrix(y_test, y_pred)
# Out:
# [[0.59834369 0.40165631]
#  [0.27350427 0.72649573]]

# %%
sensitivity = sensitivity_score(y_test, y_pred)
specificity = specificity_score(y_test, y_pred)

print("Melanoma Sensitivity:", sensitivity)
print("Melanoma Specificity:", specificity)
# Out:
# Melanoma Sensitivity: 0.7264957264957265
# Melanoma Specificity: 0.598343685300207

# %%
def plot_roc_auc(y_true, y_pred):
    """
    This function plots the ROC curves and provides the scores.
    """
    plt.figure()
    fpr, tpr, _ = roc_curve(y_true, y_pred)
    roc_auc = auc(fpr, tpr)
    print(f"ROC AUC: {roc_auc:.3f}")
    plt.plot(fpr, tpr, color="blue", lw=2,
                label='ROC curve (area = {f:.2f})'.format(d=1, f=roc_auc))
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('ROC curves')
    plt.legend(loc="lower right")
    plt.show()

plot_roc_auc(y_test, y_pred)
# Out:
# ROC AUC: 0.662

# %%
import numpy as np
from google.colab import files
from keras.preprocessing import image

uploaded = files.upload()

for fn in uploaded.keys():
 
  # predicting gambarnya
  path = fn
  img = image.load_img(path, target_size=(150, 150))
  x = image.img_to_array(img)
  x = np.expand_dims(x, axis=0)

  images = np.vstack([x])
  classes = m.predict(images, batch_size=10)
  print(classes[0])

  fig, ax = plt.subplots()
  ax.imshow(img)
  ax.axis('off')
  plt.show()

  if classes[0]>0.5:
    print(fn + "\nKanker Kulit Ganas")
  else:
    print(fn + "\nKanker Kulit Jinak")
# Out:
#      <input type="file" id="files-4e66ed32-09b3-4c5d-8e05-cebedf8e12a1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4e66ed32-09b3-4c5d-8e05-cebedf8e12a1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 1200px-Melanoma.jpg to 1200px-Melanoma (3).jpg
# [0.95597196]
# 1200px-Melanoma.jpg
# Kanker Kulit Ganas
